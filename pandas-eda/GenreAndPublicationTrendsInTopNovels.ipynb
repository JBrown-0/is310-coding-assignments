# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load your data (Make sure the DataFrame is loaded correctly before analysis)
# df = pd.read_csv('your_file.csv') # Uncomment and modify this line to load your actual dataset

# Check the first few rows of the dataframe
print(df.head())

# Check the data types and missing values
print(df.info())

# Summary statistics for numerical columns
print(df.describe())

# Check for missing values
print(df.isnull().sum())

# Optionally, drop or fill missing values based on your analysis
df = df.dropna()  # Drops rows with missing data (use carefully)
# or
# df = df.fillna(value='some_value')  # Fills missing data with a default value, if needed

# Check for duplicates
print(df.duplicated().sum())

# Optionally, remove duplicates
df = df.drop_duplicates()

# Visualizing the data

# Histogram for a numerical column (use a valid column name, e.g., 'oclc_holdings')
df['oclc_holdings'].hist(bins=50)
plt.title('Histogram of OCLC Holdings')
plt.xlabel('OCLC Holdings')
plt.ylabel('Frequency')
plt.show()

# Box plot to check for outliers in 'gr_avg_rating'
sns.boxplot(x='gr_avg_rating', data=df)
plt.title('Box Plot of Goodreads Average Rating')
plt.show()

# Scatter plot (example using 'oclc_holdings' vs 'oclc_total_editions')
sns.scatterplot(x='oclc_holdings', y='oclc_total_editions', data=df)
plt.title('Scatter Plot of OCLC Holdings vs Total Editions')
plt.xlabel('OCLC Holdings')
plt.ylabel('OCLC Total Editions')
plt.show()
# Out:
#     top_500_rank                                 title  \
# 21            22           <i>Crime and Punishment</i>
# 27            28                  <i>War and Peace</i>
# 36            37   <i>20,000 Leagues Under the Sea</i>
# 37            38                  <i>Anna Karenina</i>
# 53            54  <i>One Hundred Years of Solitude</i>
#
#                     author  pub_year orig_lang    genre author_birth  \
# 21      Fyodor Dostoyevsky      1866   Russian       na         1821
# 27             Leo Tolstoy      1869   Russian  history         1828
# 36             Jules Verne      1870    French    scifi         1828
# 37             Leo Tolstoy      1878   Russian  romance         1828
# 53  Gabriel García Márquez      1967   Spanish       na         1927
#
#    author_death author_gender author_primary_lang  ... gr_num_ratings  \
# 21         1881          male                 rus  ...        894,492
# 27         1910          male                 rus  ...        326,220
# ...
